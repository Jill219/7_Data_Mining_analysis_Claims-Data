# %%
import pandas as pd

# %% [markdown]
# ## 1. Beneficiary summary data

# %%
sample_df = pd.read_csv("sample_data/DE1_0_2008_Beneficiary_Summary_File_Sample_2.csv", index_col=0, nrows=1000)

# %%
sample_df.head(10)
# Out:
#                   BENE_BIRTH_DT  BENE_DEATH_DT  BENE_SEX_IDENT_CD  \
# DESYNPUF_ID
# 00000B48BCF4AD29       19230901            NaN                  2
# 0000525AB30E4DEF       19201001            NaN                  2
# 00009C897C3D8372       19320101            NaN                  1
# 0001168CE43BE51B       19340901            NaN                  2
# 0002E494BC87CE10       19140701            NaN                  1
# 0002EC0BCA99CACF       19421201            NaN                  1
# 0002FABBFD6D1C5C       19240701            NaN                  2
# 000364233C3E3682       19351201            NaN                  1
# 000433285C8D2349       19270901            NaN                  2
# 0004B213C9EA58EC       19421101            NaN                  2
#
#                   BENE_RACE_CD BENE_ESRD_IND  SP_STATE_CODE  BENE_COUNTY_CD  \
# DESYNPUF_ID
# 00000B48BCF4AD29             5             0             10             260
# ...

# %%
sample_df.tail(10)
# Out:
#                   BENE_BIRTH_DT  BENE_DEATH_DT  BENE_SEX_IDENT_CD  \
# DESYNPUF_ID
# 021F157F6C235A3B       19390201            NaN                  1
# 021F33E56B0426CC       19500901            NaN                  1
# 021F53913BD9E5D0       19320201            NaN                  2
# 02202AB2160421C8       19190401            NaN                  1
# 0220CB63D216D65C       19611101            NaN                  2
# 02219B9D994809B5       19350901            NaN                  1
# 02220344A5F516FE       19350301            NaN                  1
# 0222A04F2F464744       19391201            NaN                  1
# 0223656169630099       19390801            NaN                  2
# 0223B359CDEFB0D5       19541101            NaN                  1
#
#                   BENE_RACE_CD BENE_ESRD_IND  SP_STATE_CODE  BENE_COUNTY_CD  \
# DESYNPUF_ID
# 021F157F6C235A3B             1             0             13             130
# ...

# %%
sample_df.shape
# Out:
# (1000, 31)

# %%
sample_df.columns.tolist()
# Out:
# ['BENE_BIRTH_DT',
#  'BENE_DEATH_DT',
#  'BENE_SEX_IDENT_CD',
#  'BENE_RACE_CD',
#  'BENE_ESRD_IND',
#  'SP_STATE_CODE',
#  'BENE_COUNTY_CD',
#  'BENE_HI_CVRAGE_TOT_MONS',
#  'BENE_SMI_CVRAGE_TOT_MONS',
#  'BENE_HMO_CVRAGE_TOT_MONS',
#  'PLAN_CVRG_MOS_NUM',
#  'SP_ALZHDMTA',
#  'SP_CHF',
#  'SP_CHRNKIDN',
#  'SP_CNCR',
#  'SP_COPD',
#  'SP_DEPRESSN',
#  'SP_DIABETES',
#  'SP_ISCHMCHT',
#  'SP_OSTEOPRS',
#  'SP_RA_OA',
#  'SP_STRKETIA',
#  'MEDREIMB_IP',
#  'BENRES_IP',
#  'PPPYMT_IP',
#  'MEDREIMB_OP',
#  'BENRES_OP',
#  'PPPYMT_OP',
#  'MEDREIMB_CAR',
#  'BENRES_CAR',
#  'PPPYMT_CAR']

# %% [markdown]
# ### Description of beneficiary summary data

# %% [markdown]
# ![beneficiary_variables](claim_variables/beneficiary_variables.png)

# %% [markdown]
# ### Features we may need:
# * BENE_BIRTH_DT
# * BENE_DEATH_DT
# * BENE_SEX_IDENT_CD
# * BENE_RACE_CD
# * BENE_ESRD_IND
# * SP_STATE_CODE
# * BENE_COUNTY_CD
# * SP_ALZHDMTA
# * SP_CHF
# * SP_CHRNKIDN
# * SP_CNCR
# * SP_COPD
# * SP_DEPRESSN
# * SP_DIABETES
# * SP_ISCHMCHT
# * SP_OSTEOPRS
# * SP_RA_OA
# * SP_STRKETIA

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 00000B48BCF4AD29 to 0223B359CDEFB0D5
# Data columns (total 31 columns):
# BENE_BIRTH_DT               1000 non-null int64
# BENE_DEATH_DT               17 non-null float64
# BENE_SEX_IDENT_CD           1000 non-null int64
# BENE_RACE_CD                1000 non-null int64
# BENE_ESRD_IND               1000 non-null object
# SP_STATE_CODE               1000 non-null int64
# BENE_COUNTY_CD              1000 non-null int64
# BENE_HI_CVRAGE_TOT_MONS     1000 non-null int64
# BENE_SMI_CVRAGE_TOT_MONS    1000 non-null int64
# BENE_HMO_CVRAGE_TOT_MONS    1000 non-null int64
# PLAN_CVRG_MOS_NUM           1000 non-null int64
# SP_ALZHDMTA                 1000 non-null int64
# SP_CHF                      1000 non-null int64
# SP_CHRNKIDN                 1000 non-null int64
# SP_CNCR                     1000 non-null int64
# SP_COPD                     1000 non-null int64
# SP_DEPRESSN                 1000 non-null int64
# ...

# %%
sample_df.describe()
# Out:
#        BENE_BIRTH_DT  BENE_DEATH_DT  BENE_SEX_IDENT_CD  BENE_RACE_CD  \
# count   1.000000e+03   1.700000e+01        1000.000000    1000.00000
# mean    1.937494e+07   2.008066e+07           1.528000       1.27600
# std     1.281334e+05   2.980328e+02           0.499465       0.74725
# min     1.909010e+07   2.008010e+07           1.000000       1.00000
# 25%     1.929100e+07   2.008050e+07           1.000000       1.00000
# 50%     1.937105e+07   2.008070e+07           2.000000       1.00000
# 75%     1.942070e+07   2.008090e+07           2.000000       1.00000
# max     1.982020e+07   2.008120e+07           2.000000       5.00000
#
#        SP_STATE_CODE  BENE_COUNTY_CD  BENE_HI_CVRAGE_TOT_MONS  \
# count    1000.000000     1000.000000              1000.000000
# mean       25.456000      359.022000                10.947000
# std        15.452017      262.615076                 3.172105
# min         1.000000        0.000000                 0.000000
# ...

# %%
Features1 = ['BENE_BIRTH_DT',
 'BENE_DEATH_DT',
 'BENE_SEX_IDENT_CD',
 'BENE_RACE_CD',
 'BENE_ESRD_IND',
 'SP_STATE_CODE',
 'BENE_COUNTY_CD',
 'SP_ALZHDMTA',
 'SP_CHF',
 'SP_CHRNKIDN',
 'SP_CNCR',
 'SP_COPD',
 'SP_DEPRESSN',
 'SP_DIABETES',
 'SP_ISCHMCHT',
 'SP_OSTEOPRS',
 'SP_RA_OA',
 'SP_STRKETIA']

# %%
sample_beneficiary = sample_df.loc[:,Features1]

# %%
sample_beneficiary.shape
# Out:
# (1000, 18)

# %%
sample_beneficiary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 00000B48BCF4AD29 to 0223B359CDEFB0D5
# Data columns (total 18 columns):
# BENE_BIRTH_DT        1000 non-null int64
# BENE_DEATH_DT        17 non-null float64
# BENE_SEX_IDENT_CD    1000 non-null int64
# BENE_RACE_CD         1000 non-null int64
# BENE_ESRD_IND        1000 non-null object
# SP_STATE_CODE        1000 non-null int64
# BENE_COUNTY_CD       1000 non-null int64
# SP_ALZHDMTA          1000 non-null int64
# SP_CHF               1000 non-null int64
# SP_CHRNKIDN          1000 non-null int64
# SP_CNCR              1000 non-null int64
# SP_COPD              1000 non-null int64
# SP_DEPRESSN          1000 non-null int64
# SP_DIABETES          1000 non-null int64
# SP_ISCHMCHT          1000 non-null int64
# SP_OSTEOPRS          1000 non-null int64
# SP_RA_OA             1000 non-null int64
# SP_STRKETIA          1000 non-null int64
# dtypes: float64(1), int64(16), object(1)
# memory usage: 148.4+ KB

# %% [markdown]
# ### Dtypes:
# * **Datetime**: 'BENE_BIRTH_DT','BENE_DEATH_DT'
# * **Category**: 'BENE_SEX_IDENT_CD', 'BENE_RACE_CD', 'BENE_ESRD_IND', 'SP_STATE_CODE', 'BENE_COUNTY_CD'
# * **Bool**:'SP_ALZHDMTA', 'SP_CHF', 'SP_CHRNKIDN', 'SP_CNCR', 'SP_COPD', 'SP_DEPRESSN', 'SP_DIABETES', 'SP_ISCHMCHT', 'SP_OSTEOPRS', 'SP_RA_OA','SP_STRKETIA'

# %%
sample_beneficiary['BENE_SEX_IDENT_CD'].value_counts()
# Out:
# 2    528
# 1    472
# Name: BENE_SEX_IDENT_CD, dtype: int64

# %%
sample_beneficiary['BENE_RACE_CD'].value_counts()
# Out:
# 1    834
# 2    102
# 3     41
# 5     23
# Name: BENE_RACE_CD, dtype: int64

# %%
sample_beneficiary['SP_STATE_CODE'].unique()
# Out:
# array([10, 31,  7,  6,  5, 20, 49, 36, 23,  1, 42, 18, 14, 17, 52, 37, 34,
#        26, 39,  3, 46, 19, 22, 33, 13, 45,  4, 32, 54, 43, 44, 16, 50, 51,
#        29, 11, 41, 21,  9, 38, 15, 35, 28, 53, 47, 30, 24, 25,  2, 27,  8,
#        12])

# %%
sample_beneficiary['BENE_COUNTY_CD'].unique()
# Out:
# array([260, 300,  70, 200,  60, 921,  80,  50, 430,  30, 270, 210, 550,
#        141, 450, 500, 480, 640,  90, 620, 760, 988, 110, 280, 460, 170,
#        220, 150, 590, 360, 610, 820, 350, 740, 810, 540, 100, 999, 510,
#          0, 520, 530, 120, 290, 570, 690, 490, 411, 410, 400, 230,  40,
#         20, 710, 310, 940, 791, 240, 420, 380, 330, 320,  10, 331, 680,
#        130, 370, 700, 140, 780, 250, 800, 343, 340, 470, 734, 440, 180,
#        660, 843, 600, 390, 631, 948, 720, 651, 160, 892, 920, 560, 770,
#        983, 880, 900, 650, 730, 722, 670, 981, 190, 830, 191, 391, 991,
#        989, 977, 630, 970, 982, 860, 451, 641, 790, 870, 910, 750, 580,
#        471, 551, 950, 850, 992, 582, 801, 973, 890, 212, 251, 840, 891,
#        879])

# %%
sample_beneficiary['SP_ALZHDMTA'].value_counts()
# Out:
# 2    819
# 1    181
# Name: SP_ALZHDMTA, dtype: int64

# %%
splst = ['SP_ALZHDMTA', 'SP_CHF', 'SP_CHRNKIDN', 'SP_CNCR', 'SP_COPD', 'SP_DEPRESSN', 
         'SP_DIABETES', 'SP_ISCHMCHT', 'SP_OSTEOPRS', 'SP_RA_OA','SP_STRKETIA']

# %%
sample_beneficiary.loc[:,splst].apply(pd.Series.value_counts)
# Out:
#    SP_ALZHDMTA  SP_CHF  SP_CHRNKIDN  SP_CNCR  SP_COPD  SP_DEPRESSN  \
# 2          819     719          851      930      862          790
# 1          181     281          149       70      138          210
#
#    SP_DIABETES  SP_ISCHMCHT  SP_OSTEOPRS  SP_RA_OA  SP_STRKETIA
# 2          641          590          828       857          960
# 1          359          410          172       143           40

# %% [markdown]
# ## 2. Carrier claim data

# %%
sample_data2 = pd.read_csv("sample_data/DE1_0_2008_to_2010_Carrier_Claims_Sample_2A.csv", index_col = 0, nrows=1000)

# %%
sample_data2.head(10)
# Out:
#                            CLM_ID  CLM_FROM_DT  CLM_THRU_DT ICD9_DGNS_CD_1  \
# DESYNPUF_ID
# 00000B48BCF4AD29  737133358637027     20080216     20080216           7061
# 00000B48BCF4AD29  737783362300937     20080219     20080219           9561
# 00000B48BCF4AD29  737513360019665     20080220     20080220           8241
# 00000B48BCF4AD29  737553359102154     20080223     20080223           V676
# 00000B48BCF4AD29  737033360678635     20080311     20080311           5765
# 00000B48BCF4AD29  737093360154764     20080307     20080316          73320
# 00000B48BCF4AD29  737223359310755     20080322     20080322          24290
# 00000B48BCF4AD29  737603362601356     20080401     20080401          99691
# 00000B48BCF4AD29  737603361186946     20080407     20080407           4279
# 00000B48BCF4AD29  737483360372415     20080414     20080414           7235
#
#                  ICD9_DGNS_CD_2 ICD9_DGNS_CD_3 ICD9_DGNS_CD_4 ICD9_DGNS_CD_5  \
# DESYNPUF_ID
# ...

# %%
sample_data2.shape
# Out:
# (1000, 141)

# %%
sample_data2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 00000B48BCF4AD29 to 000C5BACF2F88B1E
# Data columns (total 141 columns):
# CLM_ID                           int64
# CLM_FROM_DT                      int64
# CLM_THRU_DT                      int64
# ICD9_DGNS_CD_1                   object
# ICD9_DGNS_CD_2                   object
# ICD9_DGNS_CD_3                   object
# ICD9_DGNS_CD_4                   object
# ICD9_DGNS_CD_5                   object
# ICD9_DGNS_CD_6                   float64
# ICD9_DGNS_CD_7                   object
# ICD9_DGNS_CD_8                   float64
# PRF_PHYSN_NPI_1                  float64
# PRF_PHYSN_NPI_2                  float64
# PRF_PHYSN_NPI_3                  float64
# PRF_PHYSN_NPI_4                  float64
# PRF_PHYSN_NPI_5                  float64
# PRF_PHYSN_NPI_6                  float64
# PRF_PHYSN_NPI_7                  float64
# PRF_PHYSN_NPI_8                  float64
# PRF_PHYSN_NPI_9                  float64
# ...

# %%
sample_data2.describe()
# Out:
#              CLM_ID   CLM_FROM_DT   CLM_THRU_DT  ICD9_DGNS_CD_6  \
# count  1.000000e+03  1.000000e+03  1.000000e+03       16.000000
# mean   7.374948e+14  2.008910e+07  2.008910e+07    19544.000000
# std    2.824650e+11  7.411426e+03  7.411465e+03    29374.611807
# min    7.370134e+14  2.008011e+07  2.008011e+07     2724.000000
# 25%    7.372434e+14  2.008091e+07  2.008091e+07     4848.500000
# 50%    7.374934e+14  2.009042e+07  2.009042e+07     5894.000000
# 75%    7.377259e+14  2.009120e+07  2.009120e+07    13327.000000
# max    7.379934e+14  2.010122e+07  2.010122e+07    99520.000000
#
#        ICD9_DGNS_CD_8  PRF_PHYSN_NPI_1  PRF_PHYSN_NPI_2  PRF_PHYSN_NPI_3  \
# count        4.000000     9.980000e+02     4.320000e+02     2.160000e+02
# mean     15010.250000     4.814229e+09     4.717514e+09     4.976955e+09
# std      11586.477761     2.838798e+09     2.898402e+09     2.941289e+09
# min       4011.000000     1.042292e+07     1.042292e+07     1.042292e+07
# ...

# %% [markdown]
# ### Description of variables for carrier claim data

# %% [markdown]
# ![carrier_claims](claim_variables/carrierclaim_variables.png)

# %% [markdown]
# #### #Do we need claim_ID?

# %%
features2= ['ICD9_DGNS_CD_1',
 'ICD9_DGNS_CD_2',
 'ICD9_DGNS_CD_3',
 'ICD9_DGNS_CD_4',
 'ICD9_DGNS_CD_5',
 'ICD9_DGNS_CD_6',
 'ICD9_DGNS_CD_7',
 'ICD9_DGNS_CD_8',
 'HCPCS_CD_1',
 'HCPCS_CD_2',
 'HCPCS_CD_3',
 'HCPCS_CD_4',
 'HCPCS_CD_5',
 'HCPCS_CD_6',
 'HCPCS_CD_7',
 'HCPCS_CD_8',
 'HCPCS_CD_9',
 'HCPCS_CD_10',
 'HCPCS_CD_11',
 'HCPCS_CD_12',
 'HCPCS_CD_13',]

# %%
sample_carrier = sample_data2.loc[:,features2]

# %%
sample_carrier.head(10)
# Out:
#                  ICD9_DGNS_CD_1 ICD9_DGNS_CD_2 ICD9_DGNS_CD_3 ICD9_DGNS_CD_4  \
# DESYNPUF_ID
# 00000B48BCF4AD29           7061          70211            NaN            NaN
# 00000B48BCF4AD29           9561          71945            NaN            NaN
# 00000B48BCF4AD29           8241          27651            NaN            NaN
# 00000B48BCF4AD29           V676          V5861            NaN            NaN
# 00000B48BCF4AD29           5765          56969            NaN            NaN
# 00000B48BCF4AD29          73320           7244           7392           7840
# 00000B48BCF4AD29          24290           2720           4011          41400
# 00000B48BCF4AD29          99691            NaN            NaN            NaN
# 00000B48BCF4AD29           4279            NaN            NaN            NaN
# 00000B48BCF4AD29           7235          73300            NaN            NaN
#
#                  ICD9_DGNS_CD_5  ICD9_DGNS_CD_6 ICD9_DGNS_CD_7  \
# DESYNPUF_ID
# ...

# %%
sample_carrier.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 00000B48BCF4AD29 to 000C5BACF2F88B1E
# Data columns (total 21 columns):
# ICD9_DGNS_CD_1    1000 non-null object
# ICD9_DGNS_CD_2    596 non-null object
# ICD9_DGNS_CD_3    339 non-null object
# ICD9_DGNS_CD_4    189 non-null object
# ICD9_DGNS_CD_5    26 non-null object
# ICD9_DGNS_CD_6    16 non-null float64
# ICD9_DGNS_CD_7    8 non-null object
# ICD9_DGNS_CD_8    4 non-null float64
# HCPCS_CD_1        989 non-null object
# HCPCS_CD_2        390 non-null object
# HCPCS_CD_3        190 non-null object
# HCPCS_CD_4        111 non-null object
# HCPCS_CD_5        55 non-null object
# HCPCS_CD_6        37 non-null object
# HCPCS_CD_7        28 non-null object
# HCPCS_CD_8        19 non-null object
# HCPCS_CD_9        14 non-null object
# HCPCS_CD_10       11 non-null float64
# HCPCS_CD_11       10 non-null object
# HCPCS_CD_12       8 non-null object
# HCPCS_CD_13       6 non-null object
# dtypes: float64(3), object(18)
# ...

# %%
sample_carrier.describe(include = ['object'])
# Out:
#        ICD9_DGNS_CD_1 ICD9_DGNS_CD_2 ICD9_DGNS_CD_3 ICD9_DGNS_CD_4  \
# count            1000            596            339            189
# unique            765            322            227            136
# top              4011           4019           4019           4011
# freq               24             21             12              8
#
#        ICD9_DGNS_CD_5 ICD9_DGNS_CD_7 HCPCS_CD_1 HCPCS_CD_2 HCPCS_CD_3  \
# count              26              8        989        390        190
# unique             26              8        275        209        112
# top             78702          59659      99213      A0425      36415
# freq                1              1        100         21          9
#
#        HCPCS_CD_4 HCPCS_CD_5 HCPCS_CD_6 HCPCS_CD_7 HCPCS_CD_8 HCPCS_CD_9  \
# count         111         55         37         28         19         14
# unique         68         46         32         25         18         10
# ...

# %% [markdown]
# ## 3. Inpatient claim data

# %%
sample_data3 = pd.read_csv("sample_data/DE1_0_2008_to_2010_Inpatient_Claims_Sample_2.csv", index_col=0,nrows=1000)

# %%
sample_data3.head(10)
# Out:
#                           CLM_ID  SEGMENT  CLM_FROM_DT  CLM_THRU_DT PRVDR_NUM  \
# DESYNPUF_ID
# 00000B48BCF4AD29  45461150060934        1     20080707     20080718    1000GD
# 00000B48BCF4AD29  45541150055035        1     20080724     20080726    1030RD
# 00000B48BCF4AD29  45731150068478        1     20080805     20080820    1001NA
# 0000525AB30E4DEF  45811150057351        1     20080525     20080605    3900MB
# 0000525AB30E4DEF  45391150058019        1     20080918     20080924    3100JN
# 00009C897C3D8372  45931150077792        1     20080329     20080403    0700QA
# 00009C897C3D8372  45711150102937        1     20080402     20080409    2200JJ
# 00009C897C3D8372  45221150054489        1     20080415     20080416    0700QA
# 00009C897C3D8372  45861150048241        1     20080514     20080517    0700JR
# 00009C897C3D8372  45111150044486        1     20080921     20080922    0700QA
#
#                   CLM_PMT_AMT  NCH_PRMRY_PYR_CLM_PD_AMT  AT_PHYSN_NPI  \
# DESYNPUF_ID
# ...

# %%
sample_data3.shape
# Out:
# (1000, 80)

# %%
sample_data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 00000B48BCF4AD29 to 03E739B5ED626F9E
# Data columns (total 80 columns):
# CLM_ID                            1000 non-null int64
# SEGMENT                           1000 non-null int64
# CLM_FROM_DT                       1000 non-null int64
# CLM_THRU_DT                       1000 non-null int64
# PRVDR_NUM                         1000 non-null object
# CLM_PMT_AMT                       1000 non-null float64
# NCH_PRMRY_PYR_CLM_PD_AMT          1000 non-null float64
# AT_PHYSN_NPI                      988 non-null float64
# OP_PHYSN_NPI                      578 non-null float64
# OT_PHYSN_NPI                      105 non-null float64
# CLM_ADMSN_DT                      1000 non-null int64
# ADMTNG_ICD9_DGNS_CD               992 non-null object
# CLM_PASS_THRU_PER_DIEM_AMT        1000 non-null float64
# NCH_BENE_IP_DDCTBL_AMT            958 non-null float64
# NCH_BENE_PTA_COINSRNC_LBLTY_AM    1000 non-null float64
# ...

# %% [markdown]
# ### Description of variables for inpatient claim data

# %% [markdown]
# ![inpatient_variables](claim_variables/inpatient_variables.png)

# %%
features3 = ['PRVDR_NUM',
 'CLM_ADMSN_DT',
 'NCH_BENE_DSCHRG_DT',
 'ADMTNG_ICD9_DGNS_CD',
 'CLM_DRG_CD',
 'ICD9_DGNS_CD_1',
 'ICD9_DGNS_CD_2',
 'ICD9_DGNS_CD_3',
 'ICD9_DGNS_CD_4',
 'ICD9_DGNS_CD_5',
 'ICD9_DGNS_CD_6',
 'ICD9_DGNS_CD_7',
 'ICD9_DGNS_CD_8',
 'ICD9_DGNS_CD_9',
 'ICD9_DGNS_CD_10',
 'ICD9_PRCDR_CD_1',
 'ICD9_PRCDR_CD_2',
 'ICD9_PRCDR_CD_3',
 'ICD9_PRCDR_CD_4',
 'ICD9_PRCDR_CD_5',
 'ICD9_PRCDR_CD_6',]

# %%
sample_inpatient = sample_data3.loc[:,features3]

# %%
sample_inpatient.head()
# Out:
#                  PRVDR_NUM  CLM_ADMSN_DT  NCH_BENE_DSCHRG_DT  \
# DESYNPUF_ID
# 00000B48BCF4AD29    1000GD      20080707            20080718
# 00000B48BCF4AD29    1030RD      20080724            20080726
# 00000B48BCF4AD29    1001NA      20080805            20080820
# 0000525AB30E4DEF    3900MB      20080525            20080605
# 0000525AB30E4DEF    3100JN      20080918            20080924
#
#                  ADMTNG_ICD9_DGNS_CD CLM_DRG_CD ICD9_DGNS_CD_1 ICD9_DGNS_CD_2  \
# DESYNPUF_ID
# 00000B48BCF4AD29                4280        281           4241           2760
# 00000B48BCF4AD29                4280        296          42823           2859
# 00000B48BCF4AD29               78609        263           3970           2800
# 0000525AB30E4DEF                5609        349           5609          42732
# 0000525AB30E4DEF               78906        388           5579          V4611
#
#                  ICD9_DGNS_CD_3 ICD9_DGNS_CD_4 ICD9_DGNS_CD_5  ...  \
# ...

# %%
sample_inpatient.shape
# Out:
# (1000, 21)

# %%
sample_inpatient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 00000B48BCF4AD29 to 03E739B5ED626F9E
# Data columns (total 21 columns):
# PRVDR_NUM              1000 non-null object
# CLM_ADMSN_DT           1000 non-null int64
# NCH_BENE_DSCHRG_DT     1000 non-null int64
# ADMTNG_ICD9_DGNS_CD    992 non-null object
# CLM_DRG_CD             1000 non-null object
# ICD9_DGNS_CD_1         998 non-null object
# ICD9_DGNS_CD_2         993 non-null object
# ICD9_DGNS_CD_3         987 non-null object
# ICD9_DGNS_CD_4         960 non-null object
# ICD9_DGNS_CD_5         925 non-null object
# ICD9_DGNS_CD_6         881 non-null object
# ICD9_DGNS_CD_7         820 non-null object
# ICD9_DGNS_CD_8         749 non-null object
# ICD9_DGNS_CD_9         684 non-null object
# ICD9_DGNS_CD_10        76 non-null object
# ICD9_PRCDR_CD_1        573 non-null float64
# ICD9_PRCDR_CD_2        356 non-null object
# ICD9_PRCDR_CD_3        224 non-null object
# ICD9_PRCDR_CD_4        148 non-null object
# ...

# %% [markdown]
# ### Dtype:
# * datetime: CLM_ADMSN_DT, NCH_BENE_DSCHRG_DT.
# * object: ICD9_PRCDR_CD_1.

# %%
sample_inpatient.describe(include='object')
# Out:
#        PRVDR_NUM ADMTNG_ICD9_DGNS_CD CLM_DRG_CD ICD9_DGNS_CD_1 ICD9_DGNS_CD_2  \
# count       1000                 992       1000            998            993
# unique       511                 332        451            386            412
# top       23006G                 486        188            486           4019
# freq          13                  57         12             45             59
#
#        ICD9_DGNS_CD_3 ICD9_DGNS_CD_4 ICD9_DGNS_CD_5 ICD9_DGNS_CD_6  \
# count             987            960            925            881
# unique            387            412            388            362
# top              4019           4019           4019           4019
# freq               72             47             45             39
#
#        ICD9_DGNS_CD_7 ICD9_DGNS_CD_8 ICD9_DGNS_CD_9 ICD9_DGNS_CD_10  \
# count             820            749            684              76
# unique            373            365            331              63
# ...

# %% [markdown]
# ## 4. Outpatient claim data

# %%
sample_data4 = pd.read_csv("sample_data/DE1_0_2008_to_2010_Outpatient_Claims_Sample_2.csv", index_col = 0, nrows= 1000)

# %%
sample_data4.head()
# Out:
#                            CLM_ID  SEGMENT  CLM_FROM_DT  CLM_THRU_DT  \
# DESYNPUF_ID
# 00000B48BCF4AD29  391362254696220        1   20080315.0   20080315.0
# 00000B48BCF4AD29  391612254357344        1   20080405.0   20080405.0
# 00000B48BCF4AD29  391812254100253        1   20080604.0   20080621.0
# 00000B48BCF4AD29  391012254328356        1   20081024.0   20081024.0
# 00000B48BCF4AD29  391602254471197        1   20090414.0   20090414.0
#
#                  PRVDR_NUM  CLM_PMT_AMT  NCH_PRMRY_PYR_CLM_PD_AMT  \
# DESYNPUF_ID
# 00000B48BCF4AD29    10026U         70.0                       0.0
# 00000B48BCF4AD29    0300YM         50.0                       0.0
# 00000B48BCF4AD29    1002GD        300.0                       0.0
# 00000B48BCF4AD29    1000GD       1100.0                       0.0
# 00000B48BCF4AD29    1000UU         60.0                       0.0
#
#                   AT_PHYSN_NPI  OP_PHYSN_NPI  OT_PHYSN_NPI  ...  HCPCS_CD_36  \
# ...

# %%
sample_data4.shape
# Out:
# (1000, 75)

# %%
sample_data4.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 00000B48BCF4AD29 to 00593728BA1F5D90
# Data columns (total 75 columns):
# CLM_ID                            1000 non-null int64
# SEGMENT                           1000 non-null int64
# CLM_FROM_DT                       986 non-null float64
# CLM_THRU_DT                       986 non-null float64
# PRVDR_NUM                         1000 non-null object
# CLM_PMT_AMT                       1000 non-null float64
# NCH_PRMRY_PYR_CLM_PD_AMT          1000 non-null float64
# AT_PHYSN_NPI                      974 non-null float64
# OP_PHYSN_NPI                      167 non-null float64
# OT_PHYSN_NPI                      309 non-null float64
# NCH_BENE_BLOOD_DDCTBL_LBLTY_AM    1000 non-null float64
# ICD9_DGNS_CD_1                    991 non-null object
# ICD9_DGNS_CD_2                    634 non-null object
# ICD9_DGNS_CD_3                    410 non-null object
# ICD9_DGNS_CD_4                    271 non-null object
# ...

# %% [markdown]
# ### Description of variables for outpatient claim data

# %% [markdown]
# ![Outpatient_variables](claim_variables/outpatient_variables.png)

# %%
feature4 = ['PRVDR_NUM',
 'ICD9_DGNS_CD_1',
 'ICD9_DGNS_CD_2',
 'ICD9_DGNS_CD_3',
 'ICD9_DGNS_CD_4',
 'ICD9_DGNS_CD_5',
 'ICD9_DGNS_CD_6',
 'ICD9_DGNS_CD_7',
 'ICD9_DGNS_CD_8',
 'ICD9_DGNS_CD_9',
 'ICD9_DGNS_CD_10',
 'ICD9_PRCDR_CD_1',
 'ICD9_PRCDR_CD_2',
 'ICD9_PRCDR_CD_3',
 'ICD9_PRCDR_CD_4',
 'ICD9_PRCDR_CD_5',
 'ICD9_PRCDR_CD_6',
 'ADMTNG_ICD9_DGNS_CD']

# HCPCS_CD?

# %%
sample_outpatient = sample_data4.loc[:,feature4]

# %%
sample_outpatient.head()
# Out:
#                  PRVDR_NUM ICD9_DGNS_CD_1 ICD9_DGNS_CD_2 ICD9_DGNS_CD_3  \
# DESYNPUF_ID
# 00000B48BCF4AD29    10026U           2721          V1250           2330
# 00000B48BCF4AD29    0300YM          72999          72981            NaN
# 00000B48BCF4AD29    1002GD           7216            NaN            NaN
# 00000B48BCF4AD29    1000GD          99671           4019          V1046
# 00000B48BCF4AD29    1000UU           7916          V7644            NaN
#
#                  ICD9_DGNS_CD_4 ICD9_DGNS_CD_5 ICD9_DGNS_CD_6 ICD9_DGNS_CD_7  \
# DESYNPUF_ID
# 00000B48BCF4AD29            NaN            NaN            NaN            NaN
# 00000B48BCF4AD29            NaN            NaN            NaN            NaN
# 00000B48BCF4AD29            NaN            NaN            NaN            NaN
# 00000B48BCF4AD29          53081          V5861           3441           2859
# 00000B48BCF4AD29            NaN            NaN            NaN            NaN
#
# ...

# %%
sample_outpatient.shape
# Out:
# (1000, 18)

# %%
sample_outpatient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 00000B48BCF4AD29 to 00593728BA1F5D90
# Data columns (total 18 columns):
# PRVDR_NUM              1000 non-null object
# ICD9_DGNS_CD_1         991 non-null object
# ICD9_DGNS_CD_2         634 non-null object
# ICD9_DGNS_CD_3         410 non-null object
# ICD9_DGNS_CD_4         271 non-null object
# ICD9_DGNS_CD_5         162 non-null object
# ICD9_DGNS_CD_6         104 non-null object
# ICD9_DGNS_CD_7         71 non-null object
# ICD9_DGNS_CD_8         42 non-null object
# ICD9_DGNS_CD_9         29 non-null object
# ICD9_DGNS_CD_10        1 non-null float64
# ICD9_PRCDR_CD_1        1 non-null float64
# ICD9_PRCDR_CD_2        0 non-null float64
# ICD9_PRCDR_CD_3        0 non-null float64
# ICD9_PRCDR_CD_4        0 non-null float64
# ICD9_PRCDR_CD_5        0 non-null float64
# ICD9_PRCDR_CD_6        0 non-null float64
# ADMTNG_ICD9_DGNS_CD    261 non-null object
# dtypes: float64(7), object(11)
# memory usage: 148.4+ KB

# %% [markdown]
# ### Dtypes:
# * **object**: 'ICD9_DGNS_CD_10', 'ICD9_PRCDR_CD_1', 'ICD9_PRCDR_CD_2', 'ICD9_PRCDR_CD_3','ICD9_PRCDR_CD_4', 'ICD9_PRCDR_CD_5', 'ICD9_PRCDR_CD_6'.

# %%
sample_outpatient.describe(include='object')
# Out:
#        PRVDR_NUM ICD9_DGNS_CD_1 ICD9_DGNS_CD_2 ICD9_DGNS_CD_3 ICD9_DGNS_CD_4  \
# count       1000            991            634            410            271
# unique       402            724            291            217            182
# top       4200YN           4019           4019           4019           4019
# freq          25             27             45             25             14
#
#        ICD9_DGNS_CD_5 ICD9_DGNS_CD_6 ICD9_DGNS_CD_7 ICD9_DGNS_CD_8  \
# count             162            104             71             42
# unique            115             85             62             39
# top              4019           4019           4019          79431
# freq                9              3              5              2
#
#        ICD9_DGNS_CD_9 ADMTNG_ICD9_DGNS_CD
# count              29                 261
# unique             27                 169
# top              4019               42731
# freq                3                   6

# %% [markdown]
# ## 5. Prescription Drug Events (PDE) sample

# %%
sample_data5 = pd.read_csv("sample_data/DE1_0_2008_to_2010_Prescription_Drug_Events_Sample_2.csv", 
                           index_col=0, nrows = 1000)

# %%
sample_data5.head()
# Out:
#                           PDE_ID   SRVC_DT  PROD_SRVC_ID  QTY_DSPNSD_NUM  \
# DESYNPUF_ID
# 00000B48BCF4AD29  83224466404678  20100207     185010401            30.0
# 00000B48BCF4AD29  83654467130740  20100312     115163303           100.0
# 00000B48BCF4AD29  83574462630098  20100421     117193205            20.0
# 00000B48BCF4AD29  83734462622581  20100427   19458016707            30.0
# 00000B48BCF4AD29  83594462991534  20100611   59746011109            30.0
#
#                   DAYS_SUPLY_NUM  PTNT_PAY_AMT  TOT_RX_CST_AMT
# DESYNPUF_ID
# 00000B48BCF4AD29              30           0.0            10.0
# 00000B48BCF4AD29              30           0.0            30.0
# 00000B48BCF4AD29              20           0.0           160.0
# 00000B48BCF4AD29              30          10.0             0.0
# 00000B48BCF4AD29              30           0.0             0.0

# %%
sample_data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 00000B48BCF4AD29 to 000A49D50DB10546
# Data columns (total 7 columns):
# PDE_ID            1000 non-null int64
# SRVC_DT           1000 non-null int64
# PROD_SRVC_ID      1000 non-null int64
# QTY_DSPNSD_NUM    1000 non-null float64
# DAYS_SUPLY_NUM    1000 non-null int64
# PTNT_PAY_AMT      1000 non-null float64
# TOT_RX_CST_AMT    1000 non-null float64
# dtypes: float64(3), int64(4)
# memory usage: 62.5+ KB

# %%
sample_data5.describe()
# Out:
#              PDE_ID       SRVC_DT  PROD_SRVC_ID  QTY_DSPNSD_NUM  \
# count  1.000000e+03  1.000000e+03  1.000000e+03     1000.000000
# mean   8.351499e+13  2.008976e+07  3.565577e+10       52.630000
# std    2.836834e+11  7.868522e+03  2.669514e+10       51.344126
# min    8.301446e+13  2.008010e+07  2.727825e+06        0.000000
# 25%    8.328447e+13  2.008092e+07  6.016274e+08       30.000000
# 50%    8.351446e+13  2.009052e+07  5.112909e+10       30.000000
# 75%    8.376446e+13  2.010013e+07  5.801605e+10       60.000000
# max    8.399447e+13  2.010112e+07  6.878830e+10      360.000000
#
#        DAYS_SUPLY_NUM  PTNT_PAY_AMT  TOT_RX_CST_AMT
# count     1000.000000   1000.000000      1000.00000
# mean        32.880000      8.560000        53.83000
# std         19.159141     22.294022        85.87669
# min          0.000000      0.000000         0.00000
# 25%         30.000000      0.000000        10.00000
# 50%         30.000000      0.000000        20.00000
# ...

# %% [markdown]
# ![PDE_variables](claim_variables/pde_variables.png)

# %% [markdown]
# ## 6. Ovarian Cancer
#
# Used inpatient, outpatient data to extract ovarian cancer patients. Ovarian Cancer ICD9 code:183.0

# %%
sample_inpatient.head()
# Out:
#                  PRVDR_NUM  CLM_ADMSN_DT  NCH_BENE_DSCHRG_DT  \
# DESYNPUF_ID
# 00000B48BCF4AD29    1000GD      20080707            20080718
# 00000B48BCF4AD29    1030RD      20080724            20080726
# 00000B48BCF4AD29    1001NA      20080805            20080820
# 0000525AB30E4DEF    3900MB      20080525            20080605
# 0000525AB30E4DEF    3100JN      20080918            20080924
#
#                  ADMTNG_ICD9_DGNS_CD CLM_DRG_CD ICD9_DGNS_CD_1 ICD9_DGNS_CD_2  \
# DESYNPUF_ID
# 00000B48BCF4AD29                4280        281           4241           2760
# 00000B48BCF4AD29                4280        296          42823           2859
# 00000B48BCF4AD29               78609        263           3970           2800
# 0000525AB30E4DEF                5609        349           5609          42732
# 0000525AB30E4DEF               78906        388           5579          V4611
#
#                  ICD9_DGNS_CD_3 ICD9_DGNS_CD_4 ICD9_DGNS_CD_5  ...  \
# ...

# %%
any(sample_inpatient.ICD9_DGNS_CD_1.unique() == '1830'),any(sample_inpatient.ICD9_DGNS_CD_2.unique() == '183')
# Out:
# (False, False)

# %%
sample_inpatient['ADMTNG_ICD9_DGNS_CD'][0:3]
# Out:
# DESYNPUF_ID
# 00000B48BCF4AD29     4280
# 00000B48BCF4AD29     4280
# 00000B48BCF4AD29    78609
# Name: ADMTNG_ICD9_DGNS_CD, dtype: object

# %%
oc = sample_inpatient[sample_inpatient['ADMTNG_ICD9_DGNS_CD'].apply(lambda ADMTNG_ICD9_DGNS_CD: str(ADMTNG_ICD9_DGNS_CD)[0:3] == '183')]

# %%
oc.shape
# Out:
# (1, 21)

# %%
oc
# Out:
#                  PRVDR_NUM  CLM_ADMSN_DT  NCH_BENE_DSCHRG_DT  \
# DESYNPUF_ID
# 034A12FF031B1D63    05018D      20081020            20081022
#
#                  ADMTNG_ICD9_DGNS_CD CLM_DRG_CD ICD9_DGNS_CD_1 ICD9_DGNS_CD_2  \
# DESYNPUF_ID
# 034A12FF031B1D63                1830        199           5119          41519
#
#                  ICD9_DGNS_CD_3 ICD9_DGNS_CD_4 ICD9_DGNS_CD_5  ...  \
# DESYNPUF_ID                                                    ...
# 034A12FF031B1D63          71590          28521          V1005  ...
#
#                  ICD9_DGNS_CD_7 ICD9_DGNS_CD_8 ICD9_DGNS_CD_9 ICD9_DGNS_CD_10  \
# DESYNPUF_ID
# 034A12FF031B1D63          33394          42789          42654             NaN
#
#                  ICD9_PRCDR_CD_1  ICD9_PRCDR_CD_2 ICD9_PRCDR_CD_3  \
# DESYNPUF_ID
# 034A12FF031B1D63          3491.0              NaN             NaN
#
#                  ICD9_PRCDR_CD_4 ICD9_PRCDR_CD_5 ICD9_PRCDR_CD_6
# DESYNPUF_ID
# ...

# %%
sample_outpatient.head()
# Out:
#                  PRVDR_NUM ICD9_DGNS_CD_1 ICD9_DGNS_CD_2 ICD9_DGNS_CD_3  \
# DESYNPUF_ID
# 00000B48BCF4AD29    10026U           2721          V1250           2330
# 00000B48BCF4AD29    0300YM          72999          72981            NaN
# 00000B48BCF4AD29    1002GD           7216            NaN            NaN
# 00000B48BCF4AD29    1000GD          99671           4019          V1046
# 00000B48BCF4AD29    1000UU           7916          V7644            NaN
#
#                  ICD9_DGNS_CD_4 ICD9_DGNS_CD_5 ICD9_DGNS_CD_6 ICD9_DGNS_CD_7  \
# DESYNPUF_ID
# 00000B48BCF4AD29            NaN            NaN            NaN            NaN
# 00000B48BCF4AD29            NaN            NaN            NaN            NaN
# 00000B48BCF4AD29            NaN            NaN            NaN            NaN
# 00000B48BCF4AD29          53081          V5861           3441           2859
# 00000B48BCF4AD29            NaN            NaN            NaN            NaN
#
# ...

# %%
any(sample_outpatient.ICD9_DGNS_CD_1.unique() == '1830')
# Out:
# False

# %%
oc = sample_inpatient[sample_inpatient['ICD9_DGNS_CD_1'].apply(lambda ICD9_DGNS_CD_1: str(ICD9_DGNS_CD_1)[0:3] == '183')]

# %%
oc.shape
# Out:
# (0, 21)

# %%
sample_outpatient[['ICD9_DGNS_CD_1']].isin(["183","1830"]).any()
# Out:
# ICD9_DGNS_CD_1    False
# dtype: bool

# %%
sample_out = pd.read_csv("sample_data/DE1_0_2008_to_2010_Outpatient_Claims_Sample_2.csv",nrows=100000,
                         index_col=0,low_memory=False)

# %%
sample_out['ICD9_DGNS_CD_1'].dtype
# Out:
# dtype('O')

# %%
oc = sample_out[sample_out['ICD9_DGNS_CD_1'].apply(lambda ICD9_DGNS_CD_1: str(ICD9_DGNS_CD_1)[0:4]=='1830')
               |sample_out['ICD9_DGNS_CD_2'].apply(lambda ICD9_DGNS_CD_2: str(ICD9_DGNS_CD_2)[0:4]=='1830')
               |sample_out['ICD9_DGNS_CD_3'].apply(lambda ICD9_DGNS_CD_3: str(ICD9_DGNS_CD_3)[0:4]=='1830')]

# %%
oc.shape
# Out:
# (90, 75)

# %%
oc.index
# Out:
# Index(['000C5BACF2F88B1E', '00801020C9ED5F4F', '0116309016E18247',
#        '020DF4937C275905', '025547E141859058', '0261884FFD15CE23',
#        '0261B2CD53FBB0FD', '028221BFB76E3E54', '033CCDBA511DE5CE',
#        '035235C236C4F8B7', '03FD636685FE0C8A', '0404A3F34FFB4D23',
#        '04807E41F499B028', '04829DC7475FACAD', '04BE8900E80E44C8',
#        '04BE8900E80E44C8', '04F18AF6B372DBB4', '050C6644757F2FF2',
#        '050F4E0F429ED383', '0575D0CC8A16A47A', '05DD6C5BF5517EFA',
#        '0623BA3C4278CB08', '06DB6E3A2AFC0315', '06EABE488878080B',
#        '06EBF51552C92D3D', '07A01FCE54D24872', '07DA693745175180',
#        '07DA693745175180', '080076B727884612', '082593D6AC41D330',
#        '083E79A08E36B46D', '0A212D73E4C0F02C', '0A5DFD616A1216B6',
#        '0ACA47C24B293EA3', '0AFA082BD32B8B18', '0B18BFB0489F00C9',
#        '0B40875F7B24701A', '0B81B5D7DE09D0E9', '0BB3BC4E7D53E1D3',
#        '0BEDF12905AA6F4B', '0C4C7D90CAF6670B', '0D7005880529BA99',
# ...

# %%
sample_in = pd.read_csv('sample_data/DE1_0_2008_to_2010_Inpatient_Claims_Sample_2.csv',nrows=100000,index_col=0,low_memory=False)

# %%
oc2 = sample_in[sample_in['ICD9_DGNS_CD_1'].apply(lambda ICD9_DGNS_CD_1: str(ICD9_DGNS_CD_1)[0:4]=='1830')
               |sample_in['ICD9_DGNS_CD_2'].apply(lambda ICD9_DGNS_CD_2: str(ICD9_DGNS_CD_2)[0:4]=='1830')
               |sample_in['ICD9_DGNS_CD_3'].apply(lambda ICD9_DGNS_CD_3: str(ICD9_DGNS_CD_3)[0:4]=='1830')]

# %%
oc2.shape
# Out:
# (69, 80)

# %%
oc2.index
# Out:
# Index(['0512D2973E28AF42', '0B18BFB0489F00C9', '24AB7926CEEDD588',
#        '24D69C67D4BCE96D', '2BA0C28F78C065AC', '2BA834F06DCEDE54',
#        '2BF1A06293EBDA55', '2E921B6F59B09EAB', '2EEC195989AA59F2',
#        '335993694B98DFD4', '33FAC9014A3BC6B2', '3E1E51724A7C22FC',
#        '3F03C95CB0FC2D71', '437BA206F5EA08A4', '4A18CF6044E4005E',
#        '4E217E9213D7182B', '522C7B5D2C80C3CC', '52CE0CE4B49F7C69',
#        '55D26E55E60FCB78', '5AF95396991E1215', '5E7B9E66D6ACD777',
#        '71B2AEACF1DF4E69', '72050CAE7F459903', '7672542D96041367',
#        '7948B020E4008B8D', '7D09AC2A41D48127', '7D5C36EFCC47CF1F',
#        '7FDF54AC97CBF160', '8807E76C7EF47648', '8AF115CDC98B6436',
#        '8BA71F28022B18AB', '8E38DA4112ACB319', '91E6A7BE14018C17',
#        '95A510768FB23595', '967B1A811418342C', '989613EE4444BB99',
#        '997918F0475C858B', '9BB6B65237695E64', '9D45B7F70BBA7DC5',
#        '9D86FC108125B979', '9D8D68F85D5BACB1', 'A1DDD0EA17A6E836',
# ...

# %%
sample_carrier = pd.read_csv('sample_data/DE1_0_2008_to_2010_Carrier_Claims_Sample_2A.csv',nrows=100000,
                             index_col=0,low_memory=False)

# %%
oc3 = sample_carrier[sample_carrier['ICD9_DGNS_CD_1'].apply(lambda ICD9_DGNS_CD_1: str(ICD9_DGNS_CD_1)[0:4]=='1830')
               |sample_carrier['ICD9_DGNS_CD_2'].apply(lambda ICD9_DGNS_CD_2: str(ICD9_DGNS_CD_2)[0:4]=='1830')
               |sample_carrier['ICD9_DGNS_CD_3'].apply(lambda ICD9_DGNS_CD_3: str(ICD9_DGNS_CD_3)[0:4]=='1830')]

# %%
oc3.shape
# Out:
# (60, 141)

# %%
oc3.index
# Out:
# Index(['0000525AB30E4DEF', '000C5BACF2F88B1E', '001539F8694D461D',
#        '006E953083DA761F', '007A9C6102CC7E82', '008778A91312CB8C',
#        '008C3C6D7CC0F81E', '008D0E35E69EA172', '008D0E35E69EA172',
#        '00B38C9A30687185', '00BB15D71678042D', '00BB2A38D3738911',
#        '00D898BF16BA74BB', '0103375B99F0BC8D', '0103375B99F0BC8D',
#        '0103375B99F0BC8D', '0113647A478EE6B9', '013D40684DD71874',
#        '0143926C75A4FA06', '01445827E5B7D288', '0171F49C2DC361AB',
#        '01C6F451CB88C53D', '01C6F451CB88C53D', '01D6F7C6CEA382A8',
#        '01ECE20E8DAF559A', '020DF4937C275905', '02121C418BA04B27',
#        '021F53913BD9E5D0', '0223656169630099', '024DD60DE85E3F48',
#        '024FFDEDBC63CCB8', '0274A5B2ACF60DD3', '0274A5B2ACF60DD3',
#        '02C1D39E506F935E', '02C555A34E85FE22', '02CA6BDC7B0B5FF6',
#        '02F7C9F6A407C149', '03260BC710225779', '03260BC710225779',
#        '0326F11F252A5418', '0335DDEF8F28ECD1', '0357976F52663EBE',
# ...
